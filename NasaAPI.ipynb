# %% [markdown]
# <a href="https://colab.research.google.com/github/theyasassri/Sample_2/blob/main/NasaAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import webbrowser
from IPython.display import Image,display

# %%
API_KEY = "B2K12AAjJmTVt3lbDliJGcdBtTYXkeQga8Gi1HxM"
URL = f"https://api.nasa.gov/planetary/apod?api_key={API_KEY}&count=3"

# %%
def fetch_space_data():
  try:
    response = requests.get(URL)
    if response.status_code == 200:
      data_list = response.json()

      for item in data_list:
        title = item.get("title")
        image_url = item.get("url")
        explanation = item.get("explanation")
        media_type = item.get("media_type")

        print("Hello Space Wanderer")
        print("-" * 40)
        print(f"Today our Destination: {title}")
        print("-"*40)
        if item.get(media_type) == "image":
          display(Image(url=image_url, width=600))
        else:
          print(f"Today is a vedio! Watch it here : {image_url}")
        print("-" * 40)
        print(f"Did you know?: {explanation[:150]}...")
    else:
      print("Connection failed")
  except Exception as e:
    print(f"System Faliure: {e}")

fetch_space_data()
# Out:
# Hello Space Wanderer
# ----------------------------------------
# Today our Destination: A Lunar Eclipse Over an Indian Peace Pagoda
# ----------------------------------------
# Today is a vedio! Watch it here : https://apod.nasa.gov/apod/image/1112/lunareclipse_devgun_900.jpg
# ----------------------------------------
# Did you know?: Our Moon turned red last week.  The reason was that during December 10, a total lunar eclipse occurred.  The above digitally superimposed image mosaic...
# Hello Space Wanderer
# ----------------------------------------
# Today our Destination: Last Look at Pluto's Charon Side
# ----------------------------------------
# Today is a vedio! Watch it here : https://apod.nasa.gov/apod/image/1507/Pluto03_NewHorizons_960.jpg
# ----------------------------------------
# Did you know?: Pluto surface is strange. As the robotic New Horizons barrels toward its closest approach to Pluto and its moons tomorrow, images already coming back ...
# Hello Space Wanderer
# ----------------------------------------
# Today our Destination: Planck Maps the Microwave Background
# ----------------------------------------
# Today is a vedio! Watch it here : https://apod.nasa.gov/apod/image/1303/cmbr_planck_960.jpg
# ----------------------------------------
# Did you know?: What is our universe made of? To help find out, ESA launched the Planck satellite to map, in unprecedented detail, slight temperature differences on t...

# %%
def launch_time_machine():
  print("Welcome to nasa api time machine")
  user_date = input("Enter a date (YYYY-MM-DD) or press Enter for today: ")

  if user_date:
    url = f"https://api.nasa.gov/planetary/apod?api_key={API_KEY}&date={user_date}"
  else:
    url = f"https://api.nasa.gov/planetary/apod?api_key={API_KEY}"

  try:
    response = requests.get(url)
    if response.status_code == 200:
      data = response.json()

      title = data.get("title")
      img_url = data.get("url")
      explanation = data.get("explanation")
      media_type = data.get("media_type")

      print(f"\n MISSION LOG: {user_date if user_date else "TODAY"}")
      print(f"TITLE:{title}\n")

      if media_type == "image":
        display(Image(url=img_url,width=600))
      else:
        print(f"It's a video! Watch it here: {img_url}")

      print(f"\nThe Science:\n{explanation}")

    elif response.status_code == 400:
      print("Note: NASA's APOD archive only goes back to June 16, 1995.")
      print("Try a date like '2021-12-25' (James Webb Telescope Launch)!")
      print("Mission Failed: check data format(YYYY-MM-DD)")
    else :
      print(f"Error {response.status_code}.Space time is unstable")

  except Exception as e:
    print(f"System Crash: {e}")

launch_time_machine()
# Out:
# Welcome to nasa api time machine
# Enter a date (YYYY-MM-DD) or press Enter for today: 2001-09-11
#
#  MISSION LOG: 2001-09-11
# TITLE:Spiral Galaxy NGC 3310 Across the Visible
# <img src="https://apod.nasa.gov/apod/image/0109/ngc3310b_hst.jpg" width="600"/>
# The Science:
# The party is still going on in spiral galaxy NGC 3310.  Roughly 100 million years ago, NGC 3310 likely collided with a smaller galaxy causing the large spiral galaxy to light up with a tremendous burst of star formation.  The changing gravity during the collision created density waves that compressed existing clouds of gas and triggered the star-forming party.  The above image composite by the Hubble Space Telescope was used to find the ages of many of the resulting clusters of stars.  To the surprise of many, some of the clusters are quite young, indicating that starburst galaxies may remain in star-burst mode for quite some time.  NGC 3310 spans about 50,000 light years, lies about 50 million light years away, and is visible with a small telescope towards the constellation of Ursa Major.

# %% [markdown]
# Download the image

# %%
def download_space_image(image_url, filename):
  try:
    response = requests.get(image_url, stream=True)
    if response.status_code == 200:
      with open(filename, "wb") as file:
        for chunk in response.iter_content(1024):
            file.write(chunk)

      print(f"Success! Image saved as:{filename}")
    else:
            print("Failed to donwload")

  except Exception as e:
            print(f"Download error: {e}")
